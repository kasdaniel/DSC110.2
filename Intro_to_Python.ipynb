# %% [markdown]
# <a href="https://colab.research.google.com/github/kasdaniel/DSC110.2/blob/main/Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 'Boston'
print (a)
# Out:
# Boston

# %%
b=2
c=3

# %%
def calculate_BMI ( weight, height):
  BMI=weight/(height**2)
  return BMI

# %%
calculate_BMI (75, 1.7)
# Out:
# 25.95155709342561

# %%
def calculate_BMI (height_m, weight_kg) :
  BMI=weight_kg/(height_m**2)
  return BMI

# %%
BMI=18
if BMI<20:
  print('underweight')
else:
  print('normal')
# Out:
# underweight

# %% [markdown]
# Libaries

# %% [markdown]
# Below is how we import libaries
# Libaries in Python have built-in function
# This demostrates using one line from np.
# mean can save you time

# %%
import pandas as pd
import numpy as np
